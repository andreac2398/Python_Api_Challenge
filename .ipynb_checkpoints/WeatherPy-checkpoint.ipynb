# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 564

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | jiexiu
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | zaozersk
# Processing Record 7 of Set 1 | bilibino
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto natales
# Processing Record 10 of Set 1 | lewistown
# Processing Record 11 of Set 1 | shimokizukuri
# Processing Record 12 of Set 1 | envira
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | tura
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | lihue
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | kone
# Processing Record 20 of Set 1 | beberibe
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          531
# Lat           531
# Lng           531
# Max Temp      531
# Humidity      531
# Cloudiness    531
# Wind Speed    531
# Country       531
# Date          531
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                       kodiak  57.7900 -152.4072      3.49        97
# 1                       jiexiu  37.0244  111.9125     21.48        23
# 2            port-aux-francais -49.3500   70.2167      4.45        74
# 3                       bethel  41.3712  -73.4140     12.02        89
# 4  edinburgh of the seven seas -37.0676  -12.3116     13.13        62
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.44      US  1714646251
# 1          84        4.57      CN  1714646251
# 2          82       13.34      TF  1714646251
# 3         100        2.06      US  1714646209
# 4          10        6.09      SH  1714646252

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             kodiak  57.7900 -152.4072      3.49        97
# 1                             jiexiu  37.0244  111.9125     21.48        23
# 2                  port-aux-francais -49.3500   70.2167      4.45        74
# 3                             bethel  41.3712  -73.4140     12.02        89
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.13        62
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        5.44      US  1714646251
# 1                84        4.57      CN  1714646251
# 2                82       13.34      TF  1714646251
# 3               100        2.06      US  1714646209
# 4                10        6.09      SH  1714646252

# %%
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, max_temps,
            edgecolor="black", linewidths=1, marker="o",  # describes line
            alpha=0.8, label="Cities") # more description

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, humidity, 
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, wind_speed, 
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities") 

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel='', ylabel=''):
    
    try:
        (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    except Exception as e:
        print("Error:", e)
        return None

    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    offset = 5 

    annotation_x = x_values.mean()
    annotation_y = y_values.mean() + offset

    plt.annotate(line_eq, (annotation_x, annotation_y),fontsize=15, color="red")

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title('Linear Regression')

    plt.show()

    return slope, intercept, r_value, p_value, std_err

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]
northern_hemi_df = pd.DataFrame(northern_hemisphere_data)

# Display sample data
northern_hemi_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    kodiak  57.7900 -152.4072      3.49        97         100        5.44
# 1    jiexiu  37.0244  111.9125     21.48        23          84        4.57
# 2    bethel  41.3712  -73.4140     12.02        89         100        2.06
# 3  zaozersk  69.4005   32.4476     -0.43        78          97        3.34
# 4  bilibino  68.0546  166.4372    -12.10        83          19        2.70
#
#   Country        Date
# 0      US  1714646251
# 1      CN  1714646251
# 2      US  1714646209
# 3      RU  1714646252
# 4      RU  1714646252

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere_data = city_data_df[city_data_df['Lat'] < 0]
southern_hemi_df = pd.DataFrame(southern_hemisphere_data)

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                  port-aux-francais -49.3500   70.2167      4.45        74
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.13        62
# 7                     puerto natales -51.7236  -72.4875      1.17        91
# 10                            envira  -7.3000  -70.2167     22.81        98
# 11                            avarua -21.2078 -159.7750     26.03        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                82       13.34      TF  1714646251
# 4                10        6.09      SH  1714646252
# 7                99        1.70      CL  1714646252
# 10               48        0.47      BR  1714646253
# 11               75        7.20      CK  1714646253

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Max Temp")

r_value = northern_hemi_df["Lat"].corr(northern_hemi_df["Max Temp"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  -0.8354599510670798

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Max Temp")

r_value = southern_hemi_df["Lat"].corr(southern_hemi_df["Max Temp"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  0.7552301046495002

# %% [markdown]
# **Discussion about the linear relationship:** In the two line regression for Temp vs Lat we can see there's a negative coorelation for the nother hermisphere but possitive for the Shouthern which might indicates several factores related to the earths geography, climate patterns and atmospheric dynamics.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Humidity")

r_value = northern_hemi_df["Lat"].corr(northern_hemi_df["Humidity"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  0.1234235118200804

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Humidity")

r_value = southern_hemi_df["Lat"].corr(southern_hemi_df["Humidity"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  0.12077867400384673

# %% [markdown]
# **Discussion about the linear relationship:** In the two line regression for Humidity vs Lat we can see they both have a  weak positive coorelation, indicating a tendency for humidity to increase slightly with increasing latitude.  however is so week, meaning that latitude alone does not strongly predict humidity levels.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Cloudiness")

r_value = northern_hemi_df["Lat"].corr(northern_hemi_df["Cloudiness"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  0.0688096808026539

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Cloudiness")

r_value = southern_hemi_df["Lat"].corr(southern_hemi_df["Cloudiness"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  0.10355784055153407

# %% [markdown]
# **Discussion about the linear relationship:** In the cloudiness vs Lat linear regressions for Noththen and Souther hemispheres theres also a very weak positive coorelation, being the nothern one on the 0 values. that only indicates lat doesnt strongly predicts cloudinnes

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Wind Speed")

r_value = northern_hemi_df["Lat"].corr(northern_hemi_df["Wind Speed"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  -0.029147205643202403

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plot_linear_regression(x_values,
                       y_values,
                       'Latitude',"Wind Speed")

r_value = southern_hemi_df["Lat"].corr(southern_hemi_df["Wind Speed"])

print("The r-value is: ", r_value)
# Out:
# The r-value is:  -0.1944110739154057

# %% [markdown]
# **Discussion about the linear relationship:** In the Wind speed vs Lat line regresion we find both Hemispheres with a negative coorelation which might indicate winds can decrese slightly on a higher lat bit becouse the coolatetion is so weak that indicates other factores are involve with this change too.
